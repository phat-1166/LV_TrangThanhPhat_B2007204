# %%
# Import library
from ultralytics.data.converter import convert_coco

# %%
# Folder paths
test_labels = './dataset/segmentTestSet/test'
# train_labels = './dataset/Segment Stones Final/train'
# valid_labels = './dataset/Segment Stones Final/valid'

# %%
# Convert from COCO dataset to YOLO dataset
convert_coco(labels_dir=test_labels, use_segments=True, save_dir=test_labels)
# convert_coco(labels_dir=train_labels, use_segments=True, save_dir=train_labels)
# convert_coco(labels_dir=valid_labels, use_segments=True, save_dir=valid_labels)
# Out:
# Annotations D:\University\LuanVan\LV_TrangThanhPhat_B2007204\dataset\segmentTestSet\test\_annotations.coco.json: 100%|██████████| 100/100 [00:00<00:00, 3125.41it/s]
# COCO data converted successfully.
# Results saved to D:\University\LuanVan\LV_TrangThanhPhat_B2007204\dataset\segmentTestSet\test2
